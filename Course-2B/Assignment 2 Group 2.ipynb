# %% [markdown]
# **Summer Course Group 1**
#
# Members of the group:
#
# 1) Syahraini Revita Puri
#
# 2) Fikry Idham Dwiyana (Group Leader)
#
# 3) Abbas Ahmad
#
# 4) Ananda Myzza Marhelio
#
# 5) Indah Resti Fauzi
#
# 6) Naeem Ur Rahman
#
# 7) Imam Chalish Rafidhul Haque

# %%
#import python libraries
import pandas as pd # Import the pandas library and give it the alias 'pd'
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv file
df = pd.read_csv("/content/Data Science Salaries 2023.csv")

# %%
#reading list of the data
df.head( )
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df.tail(6)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3749       2021               SE              FT           Data Specialist
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3749   165000             USD         165000                 US           100
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# ...

# %%
df.shape
# Out:
# (3755, 11)

# %%
#check types for all column
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
#check a particular column type
df['salary'].describe()
# Out:
# count    3.755000e+03
# mean     1.906956e+05
# std      6.716765e+05
# min      6.000000e+03
# 25%      1.000000e+05
# 50%      1.380000e+05
# 75%      1.800000e+05
# max      3.040000e+07
# Name: salary, dtype: float64

# %%
df.shape
# Out:
# (2584, 11)

# %%
# Count the number of duplicate rows
duplicate_rows = df[df.duplicated()]
num_duplicate_rows = duplicate_rows.shape[0]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {num_duplicate_rows}")

# Print the shape of the dataframe
print(f"Shape of dataframe: {df.shape}")
# Out:
# Number of duplicate rows: 1171
# Shape of dataframe: (3755, 11)

# %%
df.count() #count the number of rows
# Out:
# work_year             3755
# experience_level      3755
# employment_type       3755
# job_title             3755
# salary                3755
# salary_currency       3755
# salary_in_usd         3755
# employee_residence    3755
# remote_ratio          3755
# company_location      3755
# company_size          3755
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df.count()
# Out:
# work_year             2584
# experience_level      2584
# employment_type       2584
# job_title             2584
# salary                2584
# salary_currency       2584
# salary_in_usd         2584
# employee_residence    2584
# remote_ratio          2584
# company_location      2584
# company_size          2584
# dtype: int64

# %% [markdown]
# **Dropping the missing or null values**

# %%
print(df.isnull().sum())
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.shape
# Out:
# (2584, 11)

# %%
#get max value of the first 5 records
df['salary'].head(5).max()
# Out:
# 175000

# %% [markdown]
# **Visualize data with charts and graphs**

# %%
import matplotlib.pyplot as plt

# Assuming 'salary' and 'salary_in_usd' are columns in a DataFrame called 'df':
salary = df['salary']
salary_in_usd = df['salary_in_usd']

plt.plot(salary, salary_in_usd)  # To create a line plot
plt.show()
plt.scatter(salary,  salary_in_usd)  # To create a scatter plot
plt.show()
plt.hist(salary)  # To create a histogram
plt.show()
# ... and many more!
